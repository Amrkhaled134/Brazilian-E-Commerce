# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ast

# %%
df=pd.read_csv(r"C:\Users\SAMA\Documents\Olist\olist_sellers_dataset.csv")

# %%
df
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# ...

# %%
df_cleaned=df.copy()

# %%
df_cleaned.isna().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
df_cleaned.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_cleaned['seller_city'].value_counts(ascending=False)
# Out:
# seller_city
# sao paulo                 694
# curitiba                  127
# rio de janeiro             96
# belo horizonte             68
# ribeirao preto             52
#                          ...
# aparecida de goiania        1
# bandeirantes                1
# vitoria de santo antao      1
# palotina                    1
# leme                        1
# Name: count, Length: 611, dtype: int64

# %%
df_cleaned['seller_state'].value_counts(ascending=False)
# Out:
# seller_state
# SP    1849
# PR     349
# MG     244
# SC     190
# RJ     171
# RS     129
# GO      40
# DF      30
# ES      23
# BA      19
# CE      13
# PE       9
# PB       6
# RN       5
# MS       5
# MT       4
# RO       2
# SE       2
# AC       1
# PI       1
# MA       1
# AM       1
# PA       1
# Name: count, dtype: int64
