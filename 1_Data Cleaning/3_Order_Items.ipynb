# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ast

# %%
df=pd.read_csv(r"C:\Users\SAMA\Documents\Olist\olist_order_items_dataset.csv")

# %%
df
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df_cleaned=df.copy()

# %%
df_cleaned.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
df_cleaned['total_cost']=df_cleaned['price']+df_cleaned['freight_value']

# %%
df_cleaned
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df_cleaned['total_cost'].sum()
# Out:
# np.float64(15843553.24)

# %%
df_cleaned['items_count']=df_cleaned.groupby('order_id')['order_item_id'].transform('count')

# %%
df_cleaned.drop('items_count',axis=1,inplace=True)

# %%
df_cleaned.sample(10)
# Out:
#                                order_id  order_item_id  \
# 68091  9ba4f1229c25da86b79e5f8af0e56461              2
# 24995  38df543e1956e91a0b4ee89c4a49dbf3              1
# 44523  652dd1e43c57c5f82622cd0d4ec1c376              1
# 28857  41a75aec932b24ba50e98ba8b50b625d              1
# 97503  dd372e737332ef27597292546559253a              1
# 79035  b3c763d35ce46cf0a205b217814323ee              1
# 91422  cf70b7c4ec0170d19ee4259edded4b00              1
# 71910  a4086a85cd42acc124fd2ffe7ae22fd3              1
# 65969  96c833757e09a989bb5c13d0470d7f2a              1
# 56492  80848ca638a6e695838ebee7d2409893              2
#
#                              product_id                         seller_id  \
# 68091  17c4bd4269902c84acc14c497f282ddb  75d34ebb1bd0bd7dde40dd507b8169c3
# 24995  19c91ef95d509ea33eda93495c4d3481  06a2c3af7b3aee5d69171b0e14f0ee87
# 44523  44493ebe02de3fd58d529f40fd2944d1  f8db351d8c4c4c22c6835c19a46f01b0
# ...

# %%
df_cleaned[['price','freight_value']].describe()
# Out:
#                price  freight_value
# count  112650.000000  112650.000000
# mean      120.653739      19.990320
# std       183.633928      15.806405
# min         0.850000       0.000000
# 25%        39.900000      13.080000
# 50%        74.990000      16.260000
# 75%       134.900000      21.150000
# max      6735.000000     409.680000

# %%
df_cleaned['price'].quantile([0.5, 0.9, 0.95, 0.99])
# Out:
# 0.50     74.99
# 0.90    229.80
# 0.95    349.90
# 0.99    890.00
# Name: price, dtype: float64

# %%
df_cleaned.to_csv('order_items_clean.csv')
