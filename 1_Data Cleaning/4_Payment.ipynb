# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ast

# %%
df=pd.read_csv(r"C:\Users\SAMA\Documents\Olist\olist_order_payments_dataset.csv")

# %%
df.sample(10)
# Out:
#                                order_id  payment_sequential payment_type  \
# 55544  a92733241b636a8ffddd05c56714d32d                   1  credit_card
# 96997  b4b8e8f37818c443dd4c0c48e9a3707d                   1      voucher
# 46365  52cf0431b5bb17dae2f92c5af5595364                   1  credit_card
# 47128  66c0ba5488a397208076ece07748d0fa                   1       boleto
# 48363  7fd461d398eea64b8c3b9ff1761c6513                   2      voucher
# 26156  fbd8e4b53b733986be42e401224bd99f                   1      voucher
# 42187  0da63cb667e372bedd322ccfd284afbc                   1  credit_card
# 72593  4ecdafc07882d357b5607a05e3a1a46f                   1  credit_card
# 54190  0b843f953899d9a1d084c1f5163027c0                   1  credit_card
# 56806  d746b7265b49f240491cad6ed27e20be                   1  credit_card
#
#        payment_installments  payment_value
# 55544                     6          66.05
# 96997                     1         215.15
# ...

# %%
df.isna().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
df_cleaned=df.copy()

# %%
df_cleaned.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_cleaned['payment_value'].describe()
# Out:
# count    103886.000000
# mean        154.100380
# std         217.494064
# min           0.000000
# 25%          56.790000
# 50%         100.000000
# 75%         171.837500
# max       13664.080000
# Name: payment_value, dtype: float64

# %%
df_cleaned['payment_value'].quantile([0.5, 0.9, 0.95, 0.99])
# Out:
# 0.50     100.0000
# 0.90     297.2700
# 0.95     437.6350
# 0.99    1039.9165
# Name: payment_value, dtype: float64
